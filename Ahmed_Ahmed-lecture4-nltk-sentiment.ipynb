# %%
import pandas as pd

# %%
cols = ['IDs','timestamp','topic','author username','text']
tweets = pd.read_csv("dataset_sentiment_analysis.csv", header = None , names=cols)

# %%
tweets
# Out:
#       IDs                     timestamp    topic  author username  \
# 4       3  Mon May 11 03:17:40 UTC 2009  kindle2           tpryan
# 4       4  Mon May 11 03:18:03 UTC 2009  kindle2           vcu451
# 4       5  Mon May 11 03:18:54 UTC 2009  kindle2           chadfu
# 4       6  Mon May 11 03:19:04 UTC 2009  kindle2            SIX15
# 4       7  Mon May 11 03:21:41 UTC 2009  kindle2         yamarama
# ..    ...                           ...      ...              ...
# 2   14072  Sun Jun 14 04:31:43 UTC 2009    latex          proggit
# 0   14073  Sun Jun 14 04:32:17 UTC 2009    latex           sam33r
# 4   14074  Sun Jun 14 04:36:34 UTC 2009    latex  iamtheonlyjosie
# 0   14075  Sun Jun 14 21:36:07 UTC 2009     iran        plutopup7
# 0   14076  Sun Jun 14 21:36:17 UTC 2009     iran     captain_pete
#
#                                                  text
# 4   @stellargirl I loooooooovvvvvveee my Kindle2. ...
# 4   Reading my kindle2...  Love it... Lee childs i...
# ...

# %%
tpic_nike = tweets.loc[tweets['topic'] == 'nike']
tpic_nike
# Out:
#     IDs                     timestamp topic  author username  \
# 4    16  Mon May 11 05:05:58 UTC 2009  nike           MumsFP
# 0    17  Mon May 11 05:06:22 UTC 2009  nike      vincentx24x
# 4   173  Wed May 20 02:37:09 UTC 2009  nike    sportsgirl505
# 2   174  Wed May 20 02:38:27 UTC 2009  nike    MatrixSystems
# 2   175  Wed May 20 02:38:45 UTC 2009  nike     cadburysgirl
# 2   176  Wed May 20 02:38:50 UTC 2009  nike  AddictedToFresh
# 0   177  Wed May 20 02:39:05 UTC 2009  nike      coreysmbpro
# 4   178  Wed May 20 02:39:28 UTC 2009  nike         PRolivia
# 4   179  Wed May 20 02:40:23 UTC 2009  nike     ErrantDreams
# 4   531  Thu Jun 04 16:49:55 UTC 2009  nike      CrownRoyal8
# 0   532  Thu Jun 04 16:52:36 UTC 2009  nike             MrGQ
# 2   533  Thu Jun 04 16:53:09 UTC 2009  nike      ngngfrancis
# 4   534  Thu Jun 04 16:54:23 UTC 2009  nike      mikelongden
# 4  2139  Wed May 20 02:37:18 UTC 2009  nike       kewpiezmom
# ...

# %%
nike_tweets = tpic_nike['text'].tolist()

# %%
len(nike_tweets)
# Out:
# 25

# %%
#Liu and Hu  function 

def liu_hu_lexicon(sentence,plot=True):
    from nltk.corpus import opinion_lexicon
    from nltk.tokenize import treebank
    import pylab
    
    #from list of sentences to one sentence 
    sentence = ''.join([str(tweet) for tweet in sentence])
    
    tokenizer = treebank.TreebankWordTokenizer()
    pos_words = 0
    neg_words = 0
    tokenized_sent = [word.lower() for word in tokenizer.tokenize(sentence)]
    
    x = list(range(len(tokenized_sent)))
    y = []
    
    for word in tokenized_sent:
        if word in opinion_lexicon.positive():
            pos_words += 1
            y.append(1)
        elif word in opinion_lexicon.negative():
            neg_words +=1
            y.append(-1)
        else:
            y.append(0)
            
    
    if pos_words > neg_words: 
        print(str(10*pos_words/len(sentence.split())) +" positive")
    elif pos_words < neg_words:
        print(str(10*neg_words/len(sentence.split())) +"negative")
    elif pos_words == neg_words:
        print("neutral")
    
    if plot == True:
        pylab.plot(x,y)
        pylab.ylabel(["Negative","Neutral","Positive"])

# %%
import nltk
nltk.download('opinion_lexicon')
# Out:
# [nltk_data] Downloading package opinion_lexicon to
# [nltk_data]     C:\Users\hamda\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\opinion_lexicon.zip.
# True

# %%
liu_hu_lexicon(nike_tweets)
# Out:
# 0.41237113402061853 positive

# %%
tpic_worldcup = tweets.loc[tweets['topic'] == 'world cup 2010']
tpic_worldcup
# Out:
#     IDs                     timestamp           topic author username  \
# 4  1026  Mon May 11 05:53:33 UTC 2009  world cup 2010           biren
#
#                                                 text
# 4  Just bought my tickets for the 2010 FIFA World...

# %%
liu_hu_lexicon(tpic_worldcup["text"].tolist())
# Out:
# 0.47619047619047616 positive

# %%
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\hamda\AppData\Roaming\nltk_data...
# True

# %%
#function that uses the vader approach 

def vader_function(text):
    from nltk.sentiment import SentimentIntensityAnalyzer
    
    text = ''.join([str(tweet) for tweet in text])

    
    vader_analyzer = SentimentIntensityAnalyzer()
    print(vader_analyzer.polarity_scores(text))

# %%
dentist = tweets.loc[tweets['topic'] == 'dentist']
dentist
# Out:
#     IDs                     timestamp    topic author username  \
# 4   426  Tue Jun 02 03:29:53 UTC 2009  dentist      sardonnica
# 2   427  Tue Jun 02 03:32:14 UTC 2009  dentist        BChasnov
# 0   428  Tue Jun 02 03:32:33 UTC 2009  dentist       LILJIZZEL
# 0   429  Tue Jun 02 03:32:45 UTC 2009  dentist         giz2000
# 2   430  Tue Jun 02 03:33:30 UTC 2009  dentist  cmonaussiecmon
# 4   431  Tue Jun 02 03:33:53 UTC 2009  dentist     sorayabouby
# 0   432  Tue Jun 02 03:34:27 UTC 2009  dentist   jeffreymodest
# 0   433  Tue Jun 02 03:34:39 UTC 2009  dentist          yowneh
# 0   434  Tue Jun 02 03:34:58 UTC 2009  dentist  CWilliams_Rltr
# 4  2399  Tue Jun 02 03:29:47 UTC 2009  dentist   Erinthebigsis
# 0  2400  Tue Jun 02 03:32:10 UTC 2009  dentist   cassieeeelove
# 2  2401  Tue Jun 02 03:32:28 UTC 2009  dentist      johnnyt183
# 0  2402  Tue Jun 02 03:33:25 UTC 2009  dentist         b_bassi
# 0  2403  Tue Jun 02 03:34:23 UTC 2009  dentist           cmg11
# ...

# %%
dentist_list  = dentist["text"].tolist()
dentist_list[0]
# Out:
# 'My wrist still hurts. I have to get it looked at. I HATE the dr/dentist/scary places. :( Time to watch Eagle eye. If you want to join, txt!'

# %%
vader_function(dentist_list)
# Out:
# {'neg': 0.18, 'neu': 0.712, 'pos': 0.108, 'compound': -0.9633}
